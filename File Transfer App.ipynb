# %%
#FILE TRANSFER PROGRAM
#http://ipaddress:8000

# %%
import http.server
import socketserver
PORT = 7000
handler = http.server.SimpleHTTPRequestHandler
with socketserver.TCPServer(("", PORT), handler) as http:
    print("http server i srunning on port", PORT)
    http.serve_forever()
# Out:
# http server i srunning on port 7000

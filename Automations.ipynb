# %%
print("Whasapp Message Automation")
# Out:
# Whasapp Message Automation

# %%
import pywhatkit
pywhatkit.sendwhatmsg_instantly("mob no" , "Hi I am Sent By Python")
pywhatkit.sendwhatmsg("mob no" , "Hi I am Sent By Python" , 14,55)
pywhatkit.sendwhatmsg_to_group ("groupid" , "Hi I am Sent By Python" , 14,55)

# %%
print("Email Automation")
# Out:
# Email Automation

# %%
import smtplib
import ssl
from email.message import EmailMessage
EMAIL = "xyz@gmail.com"
APP_PASSWORD = "xxxxxxxxxxxx"
RECEIVER = "abc@gmail.com"
msg = EmailMessage()
msg["From"] = EMAIL
msg["To"] = RECEIVER
msg["Subject"] = "Hello From Python"
msg.set_content("This email is sent by python code")
context = ssl.create_default_context()
with smtplib.SMTP_SSL("smtp.gmail.com", 465 , context = context) as server :
    server.login(EMAIL, APP_PASSWORD)
    server.send_message(msg)

# %%
print("SMS Automation")
# Out:
# SMS Automation

# %%
from twilio.rest import Client
ACCOUNT_SID="xxxxxxxxxxxxxxxxxx"
AUTH_TOKEN="yyyyyyyyyyyyyyyy"
TWILIO_NUMBER="+17854537903"
RECIEVER_NUMBER="XXXXXXXXX"
Client = Client(ACCOUNT_SID, AUTH_TOKEN)
message = Client.messages.create(
    body = "Hello I am Uday ",
    from_= TWILIO_NUMBER ,
to=RECIEVER_NUMBER
)

# %%
print("Positive Negative Number Check ")
# Out:
# Positive Negative Number Check

# %%
num = int(input("Enter a number to check it is positive negative or zero: "))
if num == 0:
    print("It is Zero")
elif num > 0:
    print("It is Positive")
elif num < 0:
    print("It is Negative")
# Out:
# Enter a number to check it is positive negative or zero:  -7
# It is Negative

# %%
api_key = "your api Key"

# %%
import streamlit as st
import google.generativeai as genai

st.set_page_config(page_title="YP Bot", page_icon="", layout="centered")


key = api_key
genai.configure(api_key=key)
model = genai.GenerativeModel("gemini-2.5-flash")

st.markdown("""
    <style>
    body {
        background-color: #0a0f24;
    }
    .stButton>button {
        background-color:#0033A0;
        color:white;
        border-radius:5px;
        padding:5px 10px;
    }
    .stTextInput>div>input {
        background-color:#0a1a3a;
        color:white;
    }
    </style>
""", unsafe_allow_html=True)

# 
st.sidebar.title("Menu")
st.sidebar.write("Home")
st.sidebar.write("About")
st.sidebar.write("Contact")

# 
st.title("YP Bot")
st.write("Ask anything to the bot below")

user_input = st.text_input("Enter your question:")

if st.button("Send"):
    if user_input.strip() == "":
        st.warning("Please type something!")
    else:
        response = model.generate_content(user_input)
        st.success("YP Bot Response:")
        st.write(response.text)
# Out:
# 2025-11-25 23:53:11.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.603 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-25 23:53:11.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
